# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('Jan 2023 CPA Data.xlsx', sheet_name='in', header=2, converters={'Campus': str.strip})

# %%
df2 = pd.read_excel('February 2023 CPA Data.xlsx', converters={'Campus': str.strip})

# %%
df3 = pd.read_excel('March 2023 CPA Data.xlsx',header=2, converters={'Campus': str.strip})

# %%
df1['Month'] = pd.Timestamp('2023-01-01').strftime('%B')

# %%
df1.head(5)
# Out:
#      Student Name             Student E-mail  Student ID  \
# 0     Tao, Minjia    tao.mi@northeastern.edu     2774742
# 1     Tao, Minjia    tao.mi@northeastern.edu     2774742
# 2          Li, Ke    li.ke4@northeastern.edu     2792423
# 3          Li, Ke    li.ke4@northeastern.edu     2792423
# 4  Hwang, Jessica  hwang.je@northeastern.edu     2242666
#
#                 Program of Study                        Admit Term  \
# 0  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 1  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 2          MSCS Computer Science    Admit Term: Fall 2022 Semester
# 3          MSCS Computer Science    Admit Term: Fall 2022 Semester
# 4  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
#
#                    Campus                   Assigned Staff Had Appointment?  \
# 0  Campus: Silicon Valley  Xiong, Chung (Graduate Advisor)              Yes
# 1  Campus: Silicon Valley  Xiong, Chung (Graduate Advisor)              Yes
# 2  Campus: Silicon Valley  Xiong, Chung (Graduate Advisor)              Yes
# 3  Campus: Silicon Valley  Xiong, Chung (Graduate Advisor)              Yes
# 4   Campus: San Francisco  Xiong, Chung (Graduate Advisor)              Yes
#
#   Care Unit                        Scheduled Services  ...  \
# 0     Co-op                      Networking Questions  ...
# 1     Co-op               Mock Interview - Behavioral  ...
# 2     Co-op                Mock Interview - Technical  ...
# 3     Co-op               Mock Interview - Behavioral  ...
# 4     Co-op  Navigating the Tech Field (Bridge Align)  ...
#
#                                  Appointment Comment Attendance Created By  \
# 0  Minjia Tao: I am wondering where to know those...           Tao, Minjia
# 1  Minjia Tao: I wish to go over my resume and as...           Tao, Minjia
# 2                                                NaN                Li, Ke
# 3                                                NaN                Li, Ke
# 4  Jessica Hwang: Hi! I'd love to talk about how ...        Hwang, Jessica
#
#   Staff Organizer Name Staff Organizer ID           Staff Organizer Email  \
# 0        Zhang, Haoran            1525702  zhang.haoran1@northeastern.edu
# 1       Kothare, Aisha            1545504      kothare.a@northeastern.edu
# 2       Kothare, Aisha            1545504      kothare.a@northeastern.edu
# 3        Zhang, Haoran            1525702  zhang.haoran1@northeastern.edu
# 4       Kothare, Aisha            1545504      kothare.a@northeastern.edu
#
#   Cancelled? Cancellation Reason  \
# 0         No                 NaN
# 1        Yes     Needs to cancel
# 2         No                 NaN
# 3         No                 NaN
# 4         No                 NaN
#
#                                 Cancellation Comment Cancelled By    Month
# 0                                                NaN          NaN  January
# 1  I ask someone to review my resume but I didn’t...  Tao, Minjia  January
# 2                                                NaN          NaN  January
# 3                                                NaN          NaN  January
# 4                                                NaN          NaN  January
#
# [5 rows x 24 columns]

# %%
df2['Month'] = pd.Timestamp('2023-02-01').strftime('%B')

# %%
df2.head(5)
# Out:
#            Student Name                     Student E-mail  Student ID  \
# 0          Zhang, Jinda      zhang.jinda1@northeastern.edu     1005749
# 1          Zhang, Jinda      zhang.jinda1@northeastern.edu     1005749
# 2          Zhang, Jinda      zhang.jinda1@northeastern.edu     1005749
# 3  GarciaCastillo, Alan  garciacastillo.a@northeastern.edu     2956442
# 4          Rao, Yunxuan            rao.yu@northeastern.edu     2939572
#
#                 Program of Study                        Admit Term  \
# 0  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
# 1  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
# 2  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
# 3  MSCS Computer Science - Align    Admit Term: Fall 2021 Semester
# 4  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
#
#                  Campus                       Assigned Staff Had Appointment?  \
# 0     Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)              Yes
# 1     Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)              Yes
# 2     Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)              Yes
# 3  Campus: Boston (BOS)   Lambert, Alexis (Graduate Advisor)              Yes
# 4       Campus: Seattle  Escalera, Austin (Graduate Advisor)              Yes
#
#   Care Unit                        Scheduled Services  ...  \
# 0     Co-op               Mock Interview - Behavioral  ...
# 1     Co-op                Mock Interview - Technical  ...
# 2     Co-op                Mock Interview - Technical  ...
# 3     Co-op                Mock Interview - Technical  ...
# 4     Co-op  Navigating the Tech Field (Bridge Align)  ...
#
#                                  Appointment Comment  Attendance Created By  \
# 0                                                NaN           Zhang, Jinda
# 1  Jinda Zhang: Hi Qiuxuan, nice to mee you, happ...           Zhang, Jinda
# 2                                                NaN           Zhang, Jinda
# 3                                                NaN   GarciaCastillo, Alan
# 4  Yunxuan Rao: Hi, I just started my second seme...           Rao, Yunxuan
#
#   Staff Organizer Name Staff Organizer ID          Staff Organizer Email  \
# 0         Nguyen, Bach            1576947    nguyen.bac@northeastern.edu
# 1          Wu, Qiuxuan            2198048       wu.qiux@northeastern.edu
# 2       Patel, Dishant            1535927  patel.dishan@northeastern.edu
# 3          Wei, Mengdi            1540028       wei.men@northeastern.edu
# 4          Wei, Mengdi            1540028       wei.men@northeastern.edu
#
#   Cancelled? Cancellation Reason  \
# 0        Yes     Needs to cancel
# 1        Yes     Needs to cancel
# 2         No                 NaN
# 3         No                 NaN
# 4        Yes     Needs to cancel
#
#                                 Cancellation Comment  Cancelled By     Month
# 0                                                NaN  Zhang, Jinda  February
# 1  sorry did not notice it conflicts university e...  Zhang, Jinda  February
# 2                                                NaN           NaN  February
# 3                                                NaN           NaN  February
# 4                                                NaN  Rao, Yunxuan  February
#
# [5 rows x 26 columns]

# %%
df3['Month'] = pd.Timestamp('2023-03-01').strftime('%B')

# %%
df3.head(5)
# Out:
#         Student Name                Student E-mail  Student ID  \
# 0      Zhang, Xunyan   zhang.xuny@northeastern.edu     2199413
# 1       Brown, Megan    brown.meg@northeastern.edu     2750683
# 2  Cheng, Chia-Sheng  cheng.chia-@northeastern.edu     2682841
# 3        Yin, Jiajie     yin.jiaj@northeastern.edu     2103824
# 4        Yin, Jiajie     yin.jiaj@northeastern.edu     2103824
#
#                 Program of Study                        Admit Term  \
# 0  MSCS Computer Science - Align    Admit Term: Fall 2021 Semester
# 1  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
# 2  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 3  MSCS Computer Science - Align    Admit Term: Fall 2021 Semester
# 4  MSCS Computer Science - Align    Admit Term: Fall 2021 Semester
#
#                    Campus                   Classification             Major  \
# 0  Campus: Silicon Valley  Graduate (Spring 2023 Semester)  Computer Science
# 1   Campus: San Francisco  Graduate (Spring 2023 Semester)  Computer Science
# 2    Campus: Boston (BOS)  Graduate (Spring 2023 Semester)  Computer Science
# 3  Campus: Silicon Valley  Graduate (Spring 2023 Semester)  Computer Science
# 4  Campus: Silicon Valley  Graduate (Spring 2023 Semester)  Computer Science
#
#    Cumulative GPA                         Assigned Staff  ...  \
# 0           3.734  Olson, Annastatius (Graduate Advisor)  ...
# 1           0.000        Xiong, Chung (Graduate Advisor)  ...
# 2           4.000      Kelley, Cailyn (Graduate Advisor)  ...
# 3           3.458        Xiong, Chung (Graduate Advisor)  ...
# 4           3.458        Xiong, Chung (Graduate Advisor)  ...
#
#                                  Appointment Comment Attendance Created By  \
# 0                                                NaN         Zhang, Xunyan
# 1  Megan Brown: Hi Molly, I'm interested in learn...          Brown, Megan
# 2  Chia-Sheng Cheng: Hello, I'm Chia Sheng(Sheng)...     Cheng, Chia-Sheng
# 3                      Jiajie Yin: resume suggestion           Yin, Jiajie
# 4                      Jiajie Yin: resume suggestion           Yin, Jiajie
#
#   Staff Organizer Name  Staff Organizer ID          Staff Organizer Email  \
# 0      Zhang, Jiandong             2958903  zhang.jiando@northeastern.edu
# 1          Wu, Qiuxuan             2198048       wu.qiux@northeastern.edu
# 2      Agarwal, Arushi             1073330   agarwal.aru@northeastern.edu
# 3      Zhang, Jiandong             2958903  zhang.jiando@northeastern.edu
# 4      Zhang, Jiandong             2958903  zhang.jiando@northeastern.edu
#
#   Cancelled? Cancellation Reason    Cancellation Comment Cancelled By  Month
# 0         No                 NaN                     NaN          NaN  March
# 1         No                 NaN                     NaN          NaN  March
# 2         No                 NaN                     NaN          NaN  March
# 3        Yes     Needs to cancel  change to another time  Yin, Jiajie  March
# 4        Yes     Needs to cancel                     NaN  Yin, Jiajie  March
#
# [5 rows x 29 columns]

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (54, 24)
# (146, 26)
# (144, 29)

# %%
df1.columns
# Out:
# Index(['Student Name', 'Student E-mail', 'Student ID', 'Program of Study',
#        'Admit Term', 'Campus', 'Assigned Staff', 'Had Appointment?',
#        'Care Unit', 'Scheduled Services', 'Location', 'Scheduled Meeting Type',
#        'Appointment Type', 'Appointment Created By', 'Appointment Comment',
#        'Attendance Created By', 'Staff Organizer Name', 'Staff Organizer ID',
#        'Staff Organizer Email', 'Cancelled?', 'Cancellation Reason',
#        'Cancellation Comment', 'Cancelled By', 'Month'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Student Name', 'Student E-mail', 'Student ID', 'Program of Study',
#        'Admit Term', 'Campus', 'Assigned Staff', 'Had Appointment?',
#        'Care Unit', 'Scheduled Services', 'Scheduled Course Name',
#        'Scheduled Course Number', 'Location', 'Scheduled Meeting Type',
#        'Appointment Type', 'Appointment Created By', 'Appointment Comment',
#        'Attendance Created By', 'Staff Organizer Name', 'Staff Organizer ID',
#        'Staff Organizer Email', 'Cancelled?', 'Cancellation Reason',
#        'Cancellation Comment', 'Cancelled By', 'Month'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Student Name', 'Student E-mail', 'Student ID', 'Program of Study',
#        'Admit Term', 'Campus', 'Classification', 'Major', 'Cumulative GPA',
#        'Assigned Staff', 'Had Appointment?', 'Care Unit', 'Scheduled Services',
#        'Scheduled Course Name', 'Scheduled Course Number', 'Location',
#        'Scheduled Meeting Type', 'Appointment Type', 'Appointment Created By',
#        'Appointment Comment', 'Attendance Created By', 'Staff Organizer Name',
#        'Staff Organizer ID', 'Staff Organizer Email', 'Cancelled?',
#        'Cancellation Reason', 'Cancellation Comment', 'Cancelled By', 'Month'],
#       dtype='object')

# %%
common_cols = list(set(df1.columns).intersection(df2.columns).intersection(df3.columns))

# %%
merged_df = pd.merge(df1, df2, on=common_cols, how='outer')
merged_df = pd.merge(merged_df, df3, on=common_cols, how='outer')

# %%
merged_df
# Out:
#       Student Name                Student E-mail  Student ID  \
# 0      Tao, Minjia       tao.mi@northeastern.edu     2774742
# 1      Tao, Minjia       tao.mi@northeastern.edu     2774742
# 2           Li, Ke       li.ke4@northeastern.edu     2792423
# 3           Li, Ke       li.ke4@northeastern.edu     2792423
# 4           Li, Ke       li.ke4@northeastern.edu     2792423
# ..             ...                           ...         ...
# 339  Lee, Seunghan  lee.seungha@northeastern.edu     2605601
# 340       Tu, Xuan         tu.x@northeastern.edu     2959047
# 341       Xiao, Ya     xiao.ya1@northeastern.edu     2998292
# 342       Xiao, Ya     xiao.ya1@northeastern.edu     2998292
# 343       Xiao, Ya     xiao.ya1@northeastern.edu     2998292
#
#                   Program of Study                        Admit Term  \
# 0    MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 1    MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 2            MSCS Computer Science    Admit Term: Fall 2022 Semester
# 3            MSCS Computer Science    Admit Term: Fall 2022 Semester
# 4            MSCS Computer Science    Admit Term: Fall 2022 Semester
# ..                             ...                               ...
# 339  MSCS Computer Science - Align  Admit Term: Spring 2023 Semester
# 340  MSCS Computer Science - Align    Admit Term: Fall 2021 Semester
# 341  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 342  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
# 343  MSCS Computer Science - Align    Admit Term: Fall 2022 Semester
#
#                      Campus                       Assigned Staff  \
# 0    Campus: Silicon Valley      Xiong, Chung (Graduate Advisor)
# 1    Campus: Silicon Valley      Xiong, Chung (Graduate Advisor)
# 2    Campus: Silicon Valley      Xiong, Chung (Graduate Advisor)
# 3    Campus: Silicon Valley      Xiong, Chung (Graduate Advisor)
# 4    Campus: Silicon Valley      Xiong, Chung (Graduate Advisor)
# ..                      ...                                  ...
# 339    Campus: Boston (BOS)    Kelley, Cailyn (Graduate Advisor)
# 340         Campus: Seattle     Winter, Megan (Graduate Advisor)
# 341       Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)
# 342       Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)
# 343       Campus: Vancouver  Payamshad, Mahya (Graduate Advisor)
#
#     Had Appointment? Care Unit            Scheduled Services  ...  \
# 0                Yes     Co-op          Networking Questions  ...
# 1                Yes     Co-op   Mock Interview - Behavioral  ...
# 2                Yes     Co-op    Mock Interview - Technical  ...
# 3                Yes     Co-op   Mock Interview - Behavioral  ...
# 4                Yes     Co-op   Mock Interview - Behavioral  ...
# ..               ...       ...                           ...  ...
# 339              Yes     Co-op                 Resume Review  ...
# 340              Yes     Co-op   Mock Interview - Behavioral  ...
# 341              Yes     Co-op                 Resume Review  ...
# 342              Yes     Co-op  Co-op & Internship Questions  ...
# 343              Yes     Co-op  Co-op & Internship Questions  ...
#
#                                   Cancellation Comment Cancelled By    Month  \
# 0                                                  NaN          NaN  January
# 1    I ask someone to review my resume but I didn’t...  Tao, Minjia  January
# 2                                                  NaN          NaN  January
# 3                                                  NaN          NaN  January
# 4                                                  NaN          NaN  January
# ..                                                 ...          ...      ...
# 339                                                NaN          NaN    March
# 340                                                NaN          NaN    March
# 341                                                NaN          NaN    March
# 342                                                NaN          NaN    March
# 343                                                NaN          NaN    March
#
#     Scheduled Course Name_x Scheduled Course Number_x  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ..                      ...                       ...
# 339                     NaN                       NaN
# 340                     NaN                       NaN
# 341                     NaN                       NaN
# 342                     NaN                       NaN
# 343                     NaN                       NaN
#
#                       Classification             Major  Cumulative GPA  \
# 0                                NaN               NaN             NaN
# 1                                NaN               NaN             NaN
# 2                                NaN               NaN             NaN
# 3                                NaN               NaN             NaN
# 4                                NaN               NaN             NaN
# ..                               ...               ...             ...
# 339  Graduate (Spring 2023 Semester)  Computer Science             NaN
# 340  Graduate (Spring 2023 Semester)  Computer Science             4.0
# 341  Graduate (Spring 2023 Semester)  Computer Science             4.0
# 342  Graduate (Spring 2023 Semester)  Computer Science             4.0
# 343  Graduate (Spring 2023 Semester)  Computer Science             4.0
#
#     Scheduled Course Name_y Scheduled Course Number_y
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ..                      ...                       ...
# 339                     NaN                       NaN
# 340                     NaN                       NaN
# 341                     NaN                       NaN
# 342                     NaN                       NaN
# 343                     NaN                       NaN
#
# [344 rows x 31 columns]

# %%
merged_df.groupby('Month')['Cancelled?'].value_counts()
# Out:
# Month     Cancelled?
# February  No            122
#           Yes            24
# January   No             38
#           Yes            16
# March     No            116
#           Yes            28
# Name: Cancelled?, dtype: int64

# %%
# group data by month and cancelled status
grouped_df = merged_df.groupby('Month')['Cancelled?'].value_counts()

# plot bar graph
ax = grouped_df.unstack().plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i, label_type='edge')
ax.set_ylabel('Count')
ax.set_xlabel('Month')
plt.show()

# %%
grouped_df = merged_df.groupby('Month')['Campus'].value_counts()

# %%
grouped_df
# Out:
# Month     Campus
# February  Campus: Silicon Valley                          46
#           Campus: Boston (BOS)                            30
#           Campus: Seattle                                 28
#           Campus: Portland                                19
#           Campus: Vancouver                               19
#           Campus: San Francisco                            1
#           Enrollment Status: Eligible to Register (EL)     1
#           WA Student (MSEA)                                1
#           no room needed (XCR)                             1
# January   Campus: Silicon Valley                          19
#           Campus: Boston (BOS)                            15
#           Campus: Vancouver                               11
#           Campus: Portland                                 5
#           Campus: San Francisco                            2
#           Campus: Seattle                                  2
# March     Campus: Silicon Valley                          40
#           Campus: Boston (BOS)                            36
#           Campus: Seattle                                 27
#           Campus: Vancouver                               19
#           Campus: Portland                                18
#           Campus: San Francisco                            2
#           Campus: Siilicon Valley                          1
#           Expected Graduation December 2025                1
# Name: Campus, dtype: int64

# %%
merged_df = merged_df.replace('Campus: Siilicon Valley', 'Campus: Silicon Valley')

# %%
grouped_df = merged_df.groupby('Month')['Campus'].value_counts()

# %%
grouped_df
# Out:
# Month     Campus
# February  Campus: Silicon Valley                          46
#           Campus: Boston (BOS)                            30
#           Campus: Seattle                                 28
#           Campus: Portland                                19
#           Campus: Vancouver                               19
#           Campus: San Francisco                            1
#           Enrollment Status: Eligible to Register (EL)     1
#           WA Student (MSEA)                                1
#           no room needed (XCR)                             1
# January   Campus: Silicon Valley                          19
#           Campus: Boston (BOS)                            15
#           Campus: Vancouver                               11
#           Campus: Portland                                 5
#           Campus: San Francisco                            2
#           Campus: Seattle                                  2
# March     Campus: Silicon Valley                          41
#           Campus: Boston (BOS)                            36
#           Campus: Seattle                                 27
#           Campus: Vancouver                               19
#           Campus: Portland                                18
#           Campus: San Francisco                            2
#           Expected Graduation December 2025                1
# Name: Campus, dtype: int64
