# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Jan 2023 CPA Data.xlsx', sheet_name='in', header=2, converters={'Campus': str.strip})

# %%
df.shape
# Out:
# (54, 23)

# %%
df.columns
# Out:
# Index(['Student Name', 'Student E-mail', 'Student ID', 'Program of Study',
#        'Admit Term', 'Campus', 'Assigned Staff', 'Had Appointment?',
#        'Care Unit', 'Scheduled Services', 'Location', 'Scheduled Meeting Type',
#        'Appointment Type', 'Appointment Created By', 'Appointment Comment',
#        'Attendance Created By', 'Staff Organizer Name', 'Staff Organizer ID',
#        'Staff Organizer Email', 'Cancelled?', 'Cancellation Reason',
#        'Cancellation Comment', 'Cancelled By'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Student Name               0
# Student E-mail             0
# Student ID                 0
# Program of Study           0
# Admit Term                 0
# Campus                     0
# Assigned Staff             0
# Had Appointment?           0
# Care Unit                  0
# Scheduled Services         0
# Location                   0
# Scheduled Meeting Type     0
# Appointment Type           0
# Appointment Created By     0
# Appointment Comment       39
# Attendance Created By      0
# Staff Organizer Name       0
# Staff Organizer ID         0
# Staff Organizer Email      0
# Cancelled?                 0
# Cancellation Reason       38
# Cancellation Comment      44
# Cancelled By              38
# dtype: int64

# %%
df['Cancelled?'].value_counts()
# Out:
# No     38
# Yes    16
# Name: Cancelled?, dtype: int64

# %%
cols = ['Program of Study','Campus','Care Unit','Scheduled Services','Had Appointment?',]

# %%
for colu in cols:
    column_name = colu
    # Create a new DataFrame that groups the data by the values in the column
    grouped_df = df.groupby(column_name).size().reset_index(name='counts')
    
    # Set the plot style
    plt.style.use('ggplot')
    
    plt.figure(figsize=(20,6))

    # Create a bar plot of the counts
    bars = plt.bar(grouped_df[column_name], grouped_df['counts'])
    
    # Set the x-axis label
    plt.xlabel(column_name)

    # Set the y-axis label
    plt.ylabel('Count')

    plt.title('Counts')

    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + 0.35, yval + 0.5, yval)
    
    # Show the plot
    plt.show()
